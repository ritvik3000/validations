# %% [markdown]
# <a href="https://colab.research.google.com/github/ritvik3000/validations/blob/main/CO1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 5
b = 6
print(f"The result of {a} and {b} is {a + b}")
# Out:
# The result of 5 and 6 is 11

# %%
a = int(input("Enter first Value: "))
b = int(input("Enter second Value: "))
print(f"The value of {a} and {b} is {a + b}")
# Out:
# Enter first Value: 5
# Enter second Value: 12
# The value of 5 and 12 is 17

# %%
def add(a, b):
  return a + b

a = int(input("Enter first Value: "))
b = int(input("Enter second Value: "))
c = add(a, b)
print(f"The result of {a}, {b} is {c}")
# Out:
# Enter first Value: 20
# Enter second Value: 50
# The result of 20, 50 is 70

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
print(f"The sum of {a} and {b} is {a + b}")
print(f"The difference of {a} and {b} is {a - b}")
print(f"The product of {a} and {b} is {a * b}")
# Out:
# Enter first number: 5
# Enter second number: 3
# The sum of 5 and 3 is 8
# The difference of 5 and 3 is 2
# The product of 5 and 3 is 15
